# %%
import pandas as pd

# %%
df1 = pd.read_csv('../scripts/data.csv')

# %%
df2 = pd.read_csv('../scripts/data2.csv')

# %%
df1
# Out:
#                       name                                       state  \
# 0            Ramses Hilton                                       Cairo
# 1             Conrad Cairo                                       Cairo
# 2     Hilton Pyramids Golf                                        Giza
# 3     Cairo Pyramids Hotel                                        Giza
# 4                  Sofitel                                       Cairo
# ...                    ...                                         ...
# 1401                 Aswan  Al Shahid Mounir Bernaba Atta Allah Street
# 1402                 Aswan                           Al Bassaly Street
# 1403                 Aswan                                   Street 10
# 1404                 Aswan       Al Doctor Mohamed Yassin Elian Street
# 1405                 Aswan              Moustafa Mansour Hamada Street
#
#                              street                 lon  \
# 0                  Al Ghelal Street  31.231920049780662
# ...

# %%
df2
# Out:
#                                  name               state  \
# 0                       Ramses Hilton               Cairo
# 1                        Conrad Cairo               Cairo
# 2                Hilton Pyramids Golf                Giza
# 3     Hilton Cairo Zamalek Residences               Cairo
# 4     Fairmont Nile City Hotel, Cairo               Cairo
# ...                               ...                 ...
# 1000                            Aswan       Al Sadat Road
# 1001                            Aswan  loop from Nubialin
# 1002                     Fruit juices               Aswan
# 1003                      Zhara house               Aswan
# 1004                     State Bakery               Aswan
#
#                     district                       street  \
# 0                    Sharkas             Al Ghelal Street
# 1               Souk El A'sr  Al Matbaah Al Amireh Street
# 2                    Block 3                Al Wahat Road
# ...
